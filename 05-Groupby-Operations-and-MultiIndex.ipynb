# %% [markdown]
# ---
#
# <a href='http://www.pieriandata.com'><img src='../Pierian_Data_Logo.png'/></a>
#
# ---
#
# <center><em>Авторские права принадлежат Pierian Data Inc.</em></center>
# <center><em>Для дополнительной информации посетите наш сайт <a href='http://www.pieriandata.com'>www.pieriandata.com</a></em></center>

# %% [markdown]
# # Операции группировки данных (Groupby) и многоуровневый индекс (мульти-индекс)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Данные

# %%
df = pd.read_csv('mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## Метод groupby()

# %%
# Создаёт объект groupby, который ожидает метода агрегации
df.groupby('model_year')

# %% [markdown]
# #### Добавляем вызов метода агрегации. Чтобы использовать объект groupby, нам нужно сообщить pandas, как мы хотим агрегировать данные.
#
# Наиболее частые варианты:
#
#     mean(): среднее значение
#     sum(): сумма значений
#     size(): размер группы
#     count(): количество элементов
#     std(): среднеквадратичное отклонение (standard deviation)
#     var(): дисперсия (variance)
#     sem(): стандартная ошибка среднего (standard error of the mean)
#     describe(): суммарные статистики
#     first(): первое значение
#     last(): последнее значение
#     nth() : n-ое значение, или набор значений если n является списком
#     min(): минимальное значение
#     max(): максимальное значение
#
# Полный список функций можно посмотреть в документации: https://pandas.pydata.org/docs/reference/groupby.html

# %%
# Колонка model_year становится индексом! Теперь это НЕ название колонки, а название индекса

# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# df.groupby('model_year').mean(numeric_only=True)

df.groupby('model_year').mean()
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# avg_year = df.groupby('model_year').mean(numeric_only=True)

avg_year = df.groupby('model_year').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1943, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1942 try:
# -> 1943     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1944 except Exception as err:
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
avg_year.index
# Out:
# Int64Index([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype='int64', name='model_year')

# %%
avg_year.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'weight', 'acceleration', 'origin'], dtype='object')

# %%
avg_year['mpg']
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# df.groupby('model_year').mean(numeric_only=True)['mpg']

df.groupby('model_year').mean()['mpg']
# Out:
# model_year
# 70    17.689655
# 71    21.250000
# 72    18.714286
# 73    17.100000
# 74    22.703704
# 75    20.266667
# 76    21.573529
# 77    23.375000
# 78    24.061111
# 79    25.093103
# 80    33.696552
# 81    30.334483
# 82    31.709677
# Name: mpg, dtype: float64

# %%
df.groupby('model_year').describe()
# Out:
#              mpg                                                          \
#            count       mean       std   min     25%    50%     75%   max
# model_year
# 70          29.0  17.689655  5.339231   9.0  14.000  16.00  22.000  27.0
# 71          28.0  21.250000  6.591942  12.0  15.500  19.00  27.000  35.0
# 72          28.0  18.714286  5.435529  11.0  13.750  18.50  23.000  28.0
# 73          40.0  17.100000  4.700245  11.0  13.000  16.00  20.000  29.0
# 74          27.0  22.703704  6.420010  13.0  16.000  24.00  27.000  32.0
# 75          30.0  20.266667  4.940566  13.0  16.000  19.50  23.000  33.0
# 76          34.0  21.573529  5.889297  13.0  16.750  21.00  26.375  33.0
# 77          28.0  23.375000  6.675862  15.0  17.375  21.75  30.000  36.0
# 78          36.0  24.061111  6.898044  16.2  19.350  20.70  28.000  43.1
# 79          29.0  25.093103  6.794217  15.5  19.200  23.90  31.800  37.3
# 80          29.0  33.696552  7.037983  19.1  29.800  32.70  38.100  46.6
# ...

# %%
df.groupby('model_year').describe().transpose()
# Out:
# model_year                   70           71           72           73  \
# mpg          count    29.000000    28.000000    28.000000    40.000000
#              mean     17.689655    21.250000    18.714286    17.100000
#              std       5.339231     6.591942     5.435529     4.700245
#              min       9.000000    12.000000    11.000000    11.000000
#              25%      14.000000    15.500000    13.750000    13.000000
#              50%      16.000000    19.000000    18.500000    16.000000
#              75%      22.000000    27.000000    23.000000    20.000000
#              max      27.000000    35.000000    28.000000    29.000000
# cylinders    count    29.000000    28.000000    28.000000    40.000000
#              mean      6.758621     5.571429     5.821429     6.375000
#              std       1.724926     1.665079     2.073708     1.807215
#              min       4.000000     4.000000     3.000000     3.000000
# ...

# %% [markdown]
# ## Groupby по нескольким колонкам
#
# Давайте изучим средние значения по годам и по количеству цилиндров

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# df.groupby(['model_year','cylinders']).mean(numeric_only=True)

df.groupby(['model_year', 'cylinders']).mean()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# df.groupby(['model_year','cylinders']).mean(numeric_only=True).index

df.groupby(['model_year', 'cylinders']).mean().index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %% [markdown]
# # Мульти-индекс (MultiIndex)
#
# ## Объект MultiIndex

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# year_cyl = df.groupby(['model_year','cylinders']).mean()

year_cyl = df.groupby(['model_year', 'cylinders']).mean(numeric_only=True)

# %%
year_cyl
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
# 73         3          18.000000     70.000000  2124.000000     13.500000
#            4          22.727273    109.272727  2338.090909     17.136364
# ...

# %%
year_cyl.index
# Out:
# MultiIndex([(70, 4),
#             (70, 6),
#             (70, 8),
#             (71, 4),
#             (71, 6),
#             (71, 8),
#             (72, 3),
#             (72, 4),
#             (72, 8),
#             (73, 3),
#             (73, 4),
#             (73, 6),
#             (73, 8),
#             (74, 4),
#             (74, 6),
#             (74, 8),
#             (75, 4),
#             (75, 6),
#             (75, 8),
#             (76, 4),
#             (76, 6),
#             (76, 8),
#             (77, 3),
#             (77, 4),
#             (77, 6),
#             (77, 8),
#             (78, 4),
#             (78, 5),
#             (78, 6),
#             (78, 8),
#             (79, 4),
#             (79, 5),
#             (79, 6),
#             (79, 8),
#             (80, 3),
#             (80, 4),
#             (80, 5),
#             (80, 6),
#             (81, 4),
#             (81, 6),
#             (81, 8),
#             (82, 4),
#             (82, 6)],
# ...

# %%
year_cyl.index.levels
# Out:
# FrozenList([[70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], [3, 4, 5, 6, 8]])

# %%
year_cyl.index.names
# Out:
# FrozenList(['model_year', 'cylinders'])

# %%
# тесты с индексом
# year_cyl.loc[70:77] # можно выбирать срезы по первому индексу
idx = pd.IndexSlice
# таким способом возьмём нужные из мультииндекса и все стобцы
year_cyl.loc[idx[70:77, 3:5], :]
# таким способом возьмём нужные из мультииндекса и все стобцы
year_cyl.loc[idx[70:77, 3:5], 'mpg':'weight']
# Out:
#                             mpg  displacement       weight
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429
# 71         4          27.461538    101.846154  2056.384615
# 72         3          19.000000     70.000000  2330.000000
#            4          23.428571    111.535714  2382.642857
# 73         3          18.000000     70.000000  2124.000000
#            4          22.727273    109.272727  2338.090909
# 74         4          27.800000     96.533333  2151.466667
# 75         4          25.250000    114.833333  2489.250000
# 76         4          26.766667    106.333333  2306.600000
# 77         3          21.500000     80.000000  2720.000000
#            4          29.107143    106.500000  2205.071429

# %% [markdown]
# # Индексирование с помощью иерархического индекса
#
# Документация: https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html

# %%
year_cyl.head()
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         4          27.461538    101.846154  2056.384615     16.961538
#            6          18.000000    243.375000  3171.875000     14.750000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 71         4          1.923077
#            6          1.000000

# %% [markdown]
# ## Получаем данные на основе внешнего индекса

# %%
year_cyl.loc[70]
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
year_cyl.loc[[70, 72]]
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429     16.000000
#            6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 72         3          19.000000     70.000000  2330.000000     13.500000
#            4          23.428571    111.535714  2382.642857     17.214286
#            8          13.615385    344.846154  4228.384615     13.000000
#
#                         origin
# model_year cylinders
# 70         4          2.285714
#            6          1.000000
#            8          1.000000
# 72         3          3.000000
#            4          1.928571
#            8          1.000000

# %% [markdown]
# ## Получаем одну строку

# %%
year_cyl.loc[(70, 8)]
# Out:
# mpg               14.111111
# displacement     367.555556
# weight          3940.055556
# acceleration      11.194444
# origin             1.000000
# Name: (70, 8), dtype: float64

# %% [markdown]
# # Получаем данные на основе пересечения (cross-section) с помощью .xs()
#
# Этот метод использует параметр `key` для выборки данных на некотором уровне мульти-индекса.
#
# ## Параметры
#
#     key : метка (label) или кортеж из меток
#         Метка должна содержаться в индексе, или частично в мульти-индексе.
#     axis : {0 или 'index', 1 или 'columns'}, по умолчанию 0
#         Ось, по которой делаем пересечение.
#     level : объект, по умолчанию первые n уровней (n=1 или len(key))
#         В случае, если ключ частично содержится в мульти-индексе, то этот параметр указывает на те
#         уровни, которые следует использовать. Уровни можно указывать с помощью меток или позиции.

# %%
year_cyl.xs(key=70, axis=0, level='model_year')
# Out:
#                  mpg  displacement       weight  acceleration    origin
# cylinders
# 4          25.285714    107.000000  2292.571429     16.000000  2.285714
# 6          20.500000    199.000000  2710.500000     15.500000  1.000000
# 8          14.111111    367.555556  3940.055556     11.194444  1.000000

# %%
# Средние значения для 4 цилиндров по годам
year_cyl.xs(key=4, axis=0, level='cylinders')
# Out:
#                   mpg  displacement       weight  acceleration    origin
# model_year
# 70          25.285714    107.000000  2292.571429     16.000000  2.285714
# 71          27.461538    101.846154  2056.384615     16.961538  1.923077
# 72          23.428571    111.535714  2382.642857     17.214286  1.928571
# 73          22.727273    109.272727  2338.090909     17.136364  2.000000
# 74          27.800000     96.533333  2151.466667     16.400000  2.200000
# 75          25.250000    114.833333  2489.250000     15.833333  2.166667
# 76          26.766667    106.333333  2306.600000     16.866667  1.866667
# 77          29.107143    106.500000  2205.071429     16.064286  1.857143
# 78          29.576471    112.117647  2296.764706     16.282353  2.117647
# 79          31.525000    113.583333  2357.583333     15.991667  1.583333
# 80          34.612000    111.000000  2360.080000     17.144000  2.200000
# 81          32.814286    108.857143  2275.476190     16.466667  2.095238
# ...

# %% [markdown]
# ### Обратите внимание!
#
# Имейте ввиду, что обычно гораздо проще отфильтровать данные **перед** вызовом функции groupby(), чем после. Например, намного проще удалить строки со значениями **cylinder=4** перед вызовом groupby(), а после это сделать уже сложнее.

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно добавлять параметр numeric_only=True
#
# df[df['cylinders'].isin([6,8])].groupby(['model_year','cylinders']).mean()

df[df['cylinders'].isin([6, 8])].groupby(
    ['model_year', 'cylinders']).mean(numeric_only=True)
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 70         6          20.500000    199.000000  2710.500000     15.500000
#            8          14.111111    367.555556  3940.055556     11.194444
# 71         6          18.000000    243.375000  3171.875000     14.750000
#            8          13.428571    371.714286  4537.714286     12.214286
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 73         6          19.000000    212.250000  2917.125000     15.687500
#            8          13.200000    365.250000  4279.050000     12.250000
# 74         6          17.857143    230.428571  3320.000000     16.857143
#            8          14.200000    315.200000  4438.400000     14.700000
# 75         6          17.583333    233.750000  3398.333333     17.708333
#            8          15.666667    330.500000  4108.833333     13.166667
# ...

# %% [markdown]
# ## Поменять уровни местами
#
# - Как поменять уровни местами: https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html#swapping-levels-with-swaplevel
# - Общий метод по изменению порядка уровней: https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html#reordering-levels-with-reorder-levels

# %%
year_cyl.swaplevel().head()
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 4         70          25.285714    107.000000  2292.571429     16.000000
# 6         70          20.500000    199.000000  2710.500000     15.500000
# 8         70          14.111111    367.555556  3940.055556     11.194444
# 4         71          27.461538    101.846154  2056.384615     16.961538
# 6         71          18.000000    243.375000  3171.875000     14.750000
#
#                         origin
# cylinders model_year
# 4         70          2.285714
# 6         70          1.000000
# 8         70          1.000000
# 4         71          1.923077
# 6         71          1.000000

# %% [markdown]
# ## Сортировка мульти-индекса
#
# - https://pandas.pydata.org/pandas-docs/stable/user_guide/advanced.html#sorting-a-multiindex

# %%
year_cyl.sort_index(level='model_year', ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 82         6          28.333333    225.000000  2931.666667     16.033333
#            4          32.071429    118.571429  2402.321429     16.703571
# 81         8          26.600000    350.000000  3725.000000     19.000000
#            6          23.428571    184.000000  3093.571429     15.442857
#            4          32.814286    108.857143  2275.476190     16.466667
# 80         6          25.900000    196.500000  3145.500000     15.050000
#            5          36.400000    121.000000  2950.000000     19.900000
#            4          34.612000    111.000000  2360.080000     17.144000
#            3          23.700000     70.000000  2420.000000     12.500000
# 79         8          18.630000    321.400000  3862.900000     15.400000
#            6          22.950000    205.666667  3025.833333     15.433333
# ...

# %%
year_cyl.sort_index(level='cylinders', ascending=False)
# Out:
#                             mpg  displacement       weight  acceleration  \
# model_year cylinders
# 81         8          26.600000    350.000000  3725.000000     19.000000
# 79         8          18.630000    321.400000  3862.900000     15.400000
# 78         8          19.050000    300.833333  3563.333333     13.266667
# 77         8          16.000000    335.750000  4177.500000     13.662500
# 76         8          14.666667    324.000000  4064.666667     13.222222
# 75         8          15.666667    330.500000  4108.833333     13.166667
# 74         8          14.200000    315.200000  4438.400000     14.700000
# 73         8          13.200000    365.250000  4279.050000     12.250000
# 72         8          13.615385    344.846154  4228.384615     13.000000
# 71         8          13.428571    371.714286  4537.714286     12.214286
# 70         8          14.111111    367.555556  3940.055556     11.194444
# ...

# %% [markdown]
# # Дополнительные материалы: метод agg()
#
# Метод agg() позволяет Вам явно указать, какие именно методы агрегации следует использовать для каждой из категорий.

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ## agg() для DataFrame

# %%
# Эти строковые значения должны совпадать со встроенными названиями методов агрегации

# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно будет отдельно выбирать
# только числовые колонки перед тем, как выполнять агрегацию.
# Это можно сделать по-разному, один из вариантов - использовать select_dtypes(include=[np.number])
#
# df.select_dtypes(include=[np.number]).agg(['median','mean'])

df.agg(['median', 'mean'])
# Out:
#               mpg  cylinders  displacement       weight  acceleration  \
# median  23.000000   4.000000    148.500000  2803.500000      15.50000
# mean    23.514573   5.454774    193.425879  2970.424623      15.56809
#
#         model_year    origin
# median    76.00000  1.000000
# mean      76.01005  1.572864

# %%
# ВНИМАНИЕ! В будущих версиях Scikit-Learn нужно будет отдельно выбирать
# только числовые колонки перед тем, как выполнять агрегацию.
# Это можно сделать по-разному, один из вариантов - использовать select_dtypes(include=[np.number])
#
# df.select_dtypes(include=[np.number]).agg(['sum','mean'])[['mpg','weight']]

df.agg(['sum', 'mean'])[['mpg', 'weight']]
# Out:
#               mpg        weight
# sum   9358.800000  1.182229e+06
# mean    23.514573  2.970425e+03

# %% [markdown]
# ### Указываем методы агрегации для колонок
#
# **agg()** позволяет Вам передавать словарь, в котором ключи словаря это названия колонок, а значения словаря это методы агрегации для этих колонок.

# %%
df.agg({'mpg': ['median', 'mean'], 'weight': ['mean', 'std']})
# Out:
#               mpg       weight
# mean    23.514573  2970.424623
# median  23.000000          NaN
# std           NaN   846.841774

# %% [markdown]
# ## agg() с groupby()

# %%
df.groupby('model_year').agg(
    {'mpg': ['median', 'mean'], 'weight': ['mean', 'std']})
# Out:
#               mpg                  weight
#            median       mean         mean          std
# model_year
# 70          16.00  17.689655  3372.793103   852.868663
# 71          19.00  21.250000  2995.428571  1061.830859
# 72          18.50  18.714286  3237.714286   974.520960
# 73          16.00  17.100000  3419.025000   974.809133
# 74          24.00  22.703704  2877.925926   949.308571
# 75          19.50  20.266667  3176.800000   765.179781
# 76          21.00  21.573529  3078.735294   821.371481
# 77          21.75  23.375000  2997.357143   912.825902
# 78          20.70  24.061111  2861.805556   626.023907
# 79          23.90  25.093103  3055.344828   747.881497
# 80          32.70  33.696552  2436.655172   432.235491
# 81          31.60  30.334483  2522.931034   533.600501
# 82          32.00  31.709677  2453.548387   354.276713

# %% [markdown]
# # Мои дополнения

# %%
# тесты с индексом
# year_cyl.loc[70:77] # можно выбирать срезы по первому индексу
idx = pd.IndexSlice
# таким способом возьмём нужные из мультииндекса и все стобцы
year_cyl.loc[idx[70:77, 3:5], :]
# таким способом возьмём нужные из мультииндекса и все стобцы
year_cyl.loc[idx[70:77, 3:5], 'mpg':'weight']
# Out:
#                             mpg  displacement       weight
# model_year cylinders
# 70         4          25.285714    107.000000  2292.571429
# 71         4          27.461538    101.846154  2056.384615
# 72         3          19.000000     70.000000  2330.000000
#            4          23.428571    111.535714  2382.642857
# 73         3          18.000000     70.000000  2124.000000
#            4          22.727273    109.272727  2338.090909
# 74         4          27.800000     96.533333  2151.466667
# 75         4          25.250000    114.833333  2489.250000
# 76         4          26.766667    106.333333  2306.600000
# 77         3          21.500000     80.000000  2720.000000
#            4          29.107143    106.500000  2205.071429

# %%
# важен порядок передачи стольцеов для группировки для группировки
display(df.groupby(['cylinders', 'model_year']).mean(numeric_only=True))
display(df.groupby(['model_year', 'cylinders']).mean(numeric_only=True))
# Out:
#                             mpg  displacement       weight  acceleration  \
# cylinders model_year
# 3         72          19.000000     70.000000  2330.000000     13.500000
#           73          18.000000     70.000000  2124.000000     13.500000
#           77          21.500000     80.000000  2720.000000     13.500000
#           80          23.700000     70.000000  2420.000000     12.500000
# 4         70          25.285714    107.000000  2292.571429     16.000000
#           71          27.461538    101.846154  2056.384615     16.961538
#           72          23.428571    111.535714  2382.642857     17.214286
#           73          22.727273    109.272727  2338.090909     17.136364
#           74          27.800000     96.533333  2151.466667     16.400000
#           75          25.250000    114.833333  2489.250000     15.833333
#           76          26.766667    106.333333  2306.600000     16.866667
# ...

# %%
df.head(3)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %% [markdown]
# Если хочется применить функции агрегации к данным после агрегации,
# то нужно учесть функции, работающие только с числовыми данными.
# предварительно отсеять
# df.select_dtypes(np.number) или df.select_dtypes(include=[np.number])
# но возникает проблема, что группировочные колонки могут также не быть числовыми,
# поэтому может пригодиться другой метод
#
# `numeric_cols = df.select_dtypes(np.number).columns.difference(['model_year', 'cylinders'])
# df.groupby(['model_year', 'cylinders'])[numeric_cols].agg(['std', 'mean'])`
#
# т.е. взять эти колонки после агрегации

# %%
display(df.select_dtypes(np.number).groupby(
    ['model_year', 'cylinders']).agg(['std', 'mean']))

# %%
numeric_cols = df.select_dtypes(np.number).columns.difference([
    'model_year', 'cylinders'])
df.groupby(['model_year', 'cylinders'])[numeric_cols].agg(['std', 'mean'])
# Out:
#                      acceleration            displacement              \
#                               std       mean          std        mean
# model_year cylinders
# 70         4             2.661453  16.000000     8.660254  107.000000
#            6             0.408248  15.500000     0.816497  199.000000
#            8             2.668657  11.194444    59.076443  367.555556
# 71         4             2.536907  16.961538    23.053728  101.846154
#            6             1.000000  14.750000    11.867573  243.375000
#            8             0.755929  12.214286    32.438220  371.714286
# 72         3                  NaN  13.500000          NaN   70.000000
#            4             2.423557  17.214286    14.167221  111.535714
#            8             1.307032  13.000000    42.160104  344.846154
# 73         3                  NaN  13.500000          NaN   70.000000
#            4             2.440194  17.136364    18.926653  109.272727
# ...

# %%
# колону можно переименовать
numeric_cols = df.select_dtypes(np.number).columns.difference([
    'model_year', 'cylinders'])
df.groupby(['model_year', 'cylinders'])[
    numeric_cols].agg([('отклонился', 'std'), 'mean'])
# Out:
#                      acceleration            displacement              \
#                        отклонился       mean   отклонился        mean
# model_year cylinders
# 70         4             2.661453  16.000000     8.660254  107.000000
#            6             0.408248  15.500000     0.816497  199.000000
#            8             2.668657  11.194444    59.076443  367.555556
# 71         4             2.536907  16.961538    23.053728  101.846154
#            6             1.000000  14.750000    11.867573  243.375000
#            8             0.755929  12.214286    32.438220  371.714286
# 72         3                  NaN  13.500000          NaN   70.000000
#            4             2.423557  17.214286    14.167221  111.535714
#            8             1.307032  13.000000    42.160104  344.846154
# 73         3                  NaN  13.500000          NaN   70.000000
#            4             2.440194  17.136364    18.926653  109.272727
# ...

# %%
# указание функций агрегации для голонок
numeric_cols = df.select_dtypes(np.number).columns.difference(
    ['model_year', 'cylinders'])
print(numeric_cols)
df.groupby(['model_year', 'cylinders'])[numeric_cols].agg(mpg_std=('mpg', 'std'),
                                                          mpg_mean=(
                                                              'mpg', 'mean'),
                                                          displacement_std=(
                                                              'displacement', 'std'),
                                                          weight_mean=('weight', 'mean'))

# %%
# указание функций агрегации для голонок
numeric_cols = df.select_dtypes(np.number).columns.difference(
    ['model_year', 'cylinders'])
print(numeric_cols)
df.groupby(['model_year', 'cylinders'])[
    numeric_cols].agg({'mpg': ['max', 'min'], 'weight': 'mean'})
# Out:
# Index(['acceleration', 'displacement', 'mpg', 'origin', 'weight'], dtype='object')
#                        mpg             weight
#                        max   min         mean
# model_year cylinders
# 70         4          27.0  24.0  2292.571429
#            6          22.0  18.0  2710.500000
#            8          18.0   9.0  3940.055556
# 71         4          35.0  22.0  2056.384615
#            6          19.0  16.0  3171.875000
#            8          14.0  12.0  4537.714286
# 72         3          19.0  19.0  2330.000000
#            4          28.0  18.0  2382.642857
#            8          17.0  11.0  4228.384615
# 73         3          18.0  18.0  2124.000000
#            4          29.0  19.0  2338.090909
#            6          23.0  16.0  2917.125000
#            8          16.0  11.0  4279.050000
# 74         4          32.0  24.0  2151.466667
#            6          21.0  15.0  3320.000000
#            8          16.0  13.0  4438.400000
# ...

# %%
# без группировки агрегирующие функции применяются ко всему

numeric_cols = df.select_dtypes(np.number).columns.difference(
    ['model_year', 'cylinders'])
print(numeric_cols)
df[numeric_cols].agg({'mpg': ['max', 'min'], 'weight': 'mean'})
# Out:
# Index(['acceleration', 'displacement', 'mpg', 'origin', 'weight'], dtype='object')
#        mpg       weight
# max   46.6          NaN
# min    9.0          NaN
# mean   NaN  2970.424623
